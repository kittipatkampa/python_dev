# %% [markdown]
# # Word cloud

# %% [markdown]
# Just go to this excellent tutorial: https://github.com/amueller/word_cloud
#
# For me, I use this package in python2.7 Anaconda virtual environment. Here is how I install it:
#
# 1) Open the virtual environment, in my case `mypy27`: `source activate mypy27`
#
# 2) Just use `pip install` to install the package: `sudo pip install git+git://github.com/amueller/word_cloud.git`
#
# 3) The package is ready for you to use.
#
#
# If you are not using this package on Ubuntu, you will need to specify the font path, the path to your font file. In Mac I use this path: `font_path='/Library/Fonts/AppleGothic.ttf'`

# %%
#!/usr/bin/env python2
"""
Minimal Example
===============
Generating a square wordcloud from the US constitution using default arguments.
"""

from os import path
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
d = path.dirname('/Users/kittipat/research/python_dev/word_cloud-master/examples/')
d
# Out:
# '/Users/kittipat/research/python_dev/word_cloud-master/examples'

# %%
# Read the whole text.
text = open(path.join(d, 'constitution.txt')).read()
wordcloud = WordCloud(font_path='/Library/Fonts/AppleGothic.ttf').generate(text)
# Open a plot of the generated image.
fig1 = plt.gcf()
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
fig1.savefig('word_cloud_claim.png', dpi = 300)
